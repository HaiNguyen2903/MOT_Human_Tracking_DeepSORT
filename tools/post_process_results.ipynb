# %%
import os

path = '/data.local/all/hainp/yolov5_deep_sort/deep_sort_copy/inference/test_output/NVR-CH01_S20210608-084648_E20210608-084709.txt'

file = open(path, 'r')
lines = file.readlines()

# %%
for line in lines:
    line = line.strip()
# Out:
# ['2 1 910 109 218 496 -1 -1 -1 -1 \n',
#  '3 1 895 118 221 505 -1 -1 -1 -1 \n',
#  '4 1 877 121 226 517 -1 -1 -1 -1 \n',
#  '5 1 856 119 231 527 -1 -1 -1 -1 \n',
#  '6 1 828 121 242 554 -1 -1 -1 -1 \n',
#  '7 1 808 129 250 571 -1 -1 -1 -1 \n',
#  '8 1 783 142 261 591 -1 -1 -1 -1 \n',
#  '9 1 765 148 264 598 -1 -1 -1 -1 \n',
#  '10 1 740 150 266 605 -1 -1 -1 -1 \n',
#  '11 1 720 154 268 611 -1 -1 -1 -1 \n',
#  '12 1 687 169 274 624 -1 -1 -1 -1 \n',
#  '13 1 664 179 278 633 -1 -1 -1 -1 \n',
#  '14 1 629 185 286 648 -1 -1 -1 -1 \n',
#  '15 1 594 189 290 656 -1 -1 -1 -1 \n',
#  '16 1 541 197 306 697 -1 -1 -1 -1 \n',
#  '17 1 506 208 315 712 -1 -1 -1 -1 \n',
#  '18 1 474 227 322 715 -1 -1 -1 -1 \n',
#  '19 1 440 242 335 740 -1 -1 -1 -1 \n',
#  '20 1 402 250 342 759 -1 -1 -1 -1 \n',
#  '21 1 374 256 343 766 -1 -1 -1 -1 \n',
#  '22 1 336 277 351 779 -1 -1 -1 -1 \n',
#  '23 1 312 294 351 777 -1 -1 -1 -1 \n',
#  '24 1 265 317 353 762 -1 -1 -1 -1 \n',
#  '25 1 221 328 353 751 -1 -1 -1 -1 \n',
# ...
